# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'd:\\AI Course\\Second Semester\\Capstone 2\\Capstone-2\\Notebook'

# %%
df=pd.read_csv("../data/Coffee Shop Sales.csv")

# %%
df.head()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       01-01-2023         07:06:11                2
# 1               2       01-01-2023         07:08:56                2
# 2               3       01-01-2023         07:14:04                2
# 3               4       01-01-2023         07:20:24                1
# 4               5       01-01-2023         07:22:41                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32         3.0              Coffee
# 1         5  Lower Manhattan          57         3.1                 Tea
# 2         5  Lower Manhattan          59         4.5  Drinking Chocolate
# 3         5  Lower Manhattan          22         2.0              Coffee
# 4         5  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# 1        Brewed Chai tea     Spicy Eye Opener Chai Lg
# 2          Hot chocolate            Dark chocolate Lg
# 3            Drip coffee  Our Old Time Diner Blend Sm
# 4        Brewed Chai tea     Spicy Eye Opener Chai Lg

# %%
df=pd.read_csv("d:\\AI Course\\Second Semester\\Capstone 2\\Capstone-2\\data\Coffee Shop Sales.csv")

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       01-01-2023         07:06:11                2
# 1                    2       01-01-2023         07:08:56                2
# 2                    3       01-01-2023         07:14:04                2
# 3                    4       01-01-2023         07:20:24                1
# 4                    5       01-01-2023         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       30-06-2023         20:18:41                2
# 149112          149453       30-06-2023         20:25:10                2
# 149113          149454       30-06-2023         20:31:34                1
# 149114          149455       30-06-2023         20:57:19                1
# 149115          149456       30-06-2023         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# 0              5  Lower Manhattan          32        3.00              Coffee
# 1              5  Lower Manhattan          57        3.10                 Tea
# 2              5  Lower Manhattan          59        4.50  Drinking Chocolate
# 3              5  Lower Manhattan          22        2.00              Coffee
# 4              5  Lower Manhattan          57        3.10                 Tea
# ...          ...              ...         ...         ...                 ...
# 149111         8   Hell's Kitchen          44        2.50                 Tea
# 149112         8   Hell's Kitchen          49        3.00                 Tea
# 149113         8   Hell's Kitchen          45        3.00                 Tea
# 149114         8   Hell's Kitchen          40        3.75              Coffee
# 149115         8   Hell's Kitchen          64        0.80            Flavours
#
#                  product_type               product_detail
# 0       Gourmet brewed coffee                  Ethiopia Rg
# 1             Brewed Chai tea     Spicy Eye Opener Chai Lg
# 2               Hot chocolate            Dark chocolate Lg
# 3                 Drip coffee  Our Old Time Diner Blend Sm
# 4             Brewed Chai tea     Spicy Eye Opener Chai Lg
# ...                       ...                          ...
# 149111      Brewed herbal tea                Peppermint Rg
# 149112       Brewed Black tea         English Breakfast Lg
# 149113      Brewed herbal tea                Peppermint Lg
# 149114       Barista Espresso                   Cappuccino
# 149115          Regular syrup               Hazelnut syrup
#
# [149116 rows x 11 columns]

# %%
df.describe()
# Out:
#        transaction_id  transaction_qty       store_id     product_id  \
# count   149116.000000    149116.000000  149116.000000  149116.000000
# mean     74737.371872         1.438276       5.342063      47.918607
# std      43153.600016         0.542509       2.074241      17.930020
# min          1.000000         1.000000       3.000000       1.000000
# 25%      37335.750000         1.000000       3.000000      33.000000
# 50%      74727.500000         1.000000       5.000000      47.000000
# 75%     112094.250000         2.000000       8.000000      60.000000
# max     149456.000000         8.000000       8.000000      87.000000
#
#           unit_price
# count  149116.000000
# mean        3.382219
# std         2.658723
# min         0.800000
# 25%         2.500000
# 50%         3.000000
# 75%         3.750000
# max        45.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  object
#  2   transaction_time  149116 non-null  object
#  3   transaction_qty   149116 non-null  int64
#  4   store_id          149116 non-null  int64
#  5   store_location    149116 non-null  object
#  6   product_id        149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   product_category  149116 non-null  object
#  9   product_type      149116 non-null  object
#  10  product_detail    149116 non-null  object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 12.5+ MB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Convert transaction_date to datetime for time series analysis
df["transaction_date"] = pd.to_datetime(df["transaction_date"], format="%d-%m-%Y", errors="coerce")

# Aggregate total quantity sold per store
store_sales = df.groupby("store_id")["transaction_qty"].sum().reset_index()

# Aggregate total quantity sold per product category
category_sales = df.groupby("product_category")["transaction_qty"].sum().reset_index()

# Aggregate total quantity sold per product type
type_sales = df.groupby("product_type")["transaction_qty"].sum().reset_index()

# %%
df["transaction_date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  datetime64[ns]
#  2   transaction_time  149116 non-null  object
#  3   transaction_qty   149116 non-null  int64
#  4   store_id          149116 non-null  int64
#  5   store_location    149116 non-null  object
#  6   product_id        149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   product_category  149116 non-null  object
#  9   product_type      149116 non-null  object
#  10  product_detail    149116 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 12.5+ MB

# %%
# Set up the plotting style
sns.set_style("whitegrid")

# Plot total quantity sold per store
plt.figure(figsize=(12, 5))
sns.barplot(x="store_id", y="transaction_qty", data=store_sales, palette="Blues_r")
plt.xticks(rotation=90)
plt.title("Total Quantity Sold per Store")
plt.xlabel("Store ID")
plt.ylabel("Total Quantity Sold")
plt.show()
# Out:
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_16696\1616128021.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="store_id", y="transaction_qty", data=store_sales, palette="Blues_r")

# %%
# Plot total quantity sold per product category
plt.figure(figsize=(12, 5))
sns.barplot(x="product_category", y="transaction_qty", data=category_sales, palette="Greens_r")
plt.xticks(rotation=90)
plt.title("Total Quantity Sold per Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Quantity Sold")
plt.show()
# Out:
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_16696\329501896.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="product_category", y="transaction_qty", data=category_sales, palette="Greens_r")

# %%
# Plot total quantity sold per product type
plt.figure(figsize=(12, 5))
sns.barplot(x="product_type", y="transaction_qty", data=type_sales, palette="Oranges_r")
plt.xticks(rotation=90)
plt.title("Total Quantity Sold per Product Type")
plt.xlabel("Product Type")
plt.ylabel("Total Quantity Sold")
plt.show()
# Out:
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_16696\2271357313.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="product_type", y="transaction_qty", data=type_sales, palette="Oranges_r")

# %%
df_filtered = df[df["product_category"].isin(["Coffee", "Tea", "Bakery", "Drinking Chocolate"])]

# %%
# Aggregate total quantity sold per day per category
df_grouped = df_filtered.groupby(["transaction_date", "product_category"])["transaction_qty"].sum().reset_index()

# %%
df_grouped.shape
# Out:
# (724, 3)

# %%
# Plot time series using seaborn
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_grouped, x="transaction_date", y="transaction_qty", hue="product_category", marker="o")

# Formatting
plt.xlabel("Date")
plt.ylabel("Total Quantity Sold")
plt.title("Time Series of Product Sales (Coffee, Tea, Bakery, Drinking Chocolate)")
plt.xticks(rotation=45)
plt.legend(title="Product Category")
plt.grid()
plt.show()

# %%
# Aggregate total quantity sold per day per store
df_grouped_store = df_filtered.groupby(["transaction_date", "store_id"])["transaction_qty"].sum().reset_index()

# %%
# Plot time series using seaborn
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_grouped_store, x="transaction_date", y="transaction_qty", hue="store_id", marker="o")

# Formatting
plt.xlabel("Date")
plt.ylabel("Total Quantity Sold")
plt.title("Time Series of Product Sales by Store")
plt.xticks(rotation=45)
plt.legend(title="Store ID")
plt.grid()
plt.show()

# %%
df.hist(column="transaction_qty", bins=50, figsize=(10, 6))
plt.xlabel("Transaction Quantity")
plt.ylabel("Frequency")
plt.title("Histogram of Transaction Quantity")
plt.grid()

# %%
df["transaction_price"]=df["transaction_qty"]*df["unit_price"]

# %%
df.head()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       2023-01-01         07:06:11                2
# 1               2       2023-01-01         07:08:56                2
# 2               3       2023-01-01         07:14:04                2
# 3               4       2023-01-01         07:20:24                1
# 4               5       2023-01-01         07:22:41                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32         3.0              Coffee
# 1         5  Lower Manhattan          57         3.1                 Tea
# 2         5  Lower Manhattan          59         4.5  Drinking Chocolate
# 3         5  Lower Manhattan          22         2.0              Coffee
# 4         5  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail  transaction_price
# 0  Gourmet brewed coffee                  Ethiopia Rg                6.0
# 1        Brewed Chai tea     Spicy Eye Opener Chai Lg                6.2
# 2          Hot chocolate            Dark chocolate Lg                9.0
# 3            Drip coffee  Our Old Time Diner Blend Sm                2.0
# 4        Brewed Chai tea     Spicy Eye Opener Chai Lg                6.2

# %%
df.hist(column="transaction_price", bins=50, figsize=(10, 6))
plt.xlabel("Transaction Quantity")
plt.ylabel("Frequency")
plt.title("Histogram of Transaction Price")
plt.grid()

# %%
df.head()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       2023-01-01         07:06:11                2
# 1               2       2023-01-01         07:08:56                2
# 2               3       2023-01-01         07:14:04                2
# 3               4       2023-01-01         07:20:24                1
# 4               5       2023-01-01         07:22:41                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32         3.0              Coffee
# 1         5  Lower Manhattan          57         3.1                 Tea
# 2         5  Lower Manhattan          59         4.5  Drinking Chocolate
# 3         5  Lower Manhattan          22         2.0              Coffee
# 4         5  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail  transaction_price
# 0  Gourmet brewed coffee                  Ethiopia Rg                6.0
# 1        Brewed Chai tea     Spicy Eye Opener Chai Lg                6.2
# 2          Hot chocolate            Dark chocolate Lg                9.0
# 3            Drip coffee  Our Old Time Diner Blend Sm                2.0
# 4        Brewed Chai tea     Spicy Eye Opener Chai Lg                6.2

# %%
# Aggregate total quantity sold per day per category
df_perday = df.groupby(["transaction_date"])["transaction_qty"].sum().reset_index()

# %%
df_perday.head()
# Out:
#   transaction_date  transaction_qty
# 0       2023-01-01              802
# 1       2023-01-02              790
# 2       2023-01-03              823
# 3       2023-01-04              726
# 4       2023-01-05              778

# %%
# Plot time series using seaborn
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_perday, x="transaction_date", y="transaction_qty", marker="o")

# Formatting
plt.xlabel("Date")
plt.ylabel("Total Quantity Sold")
plt.title("Time Series of Product Sales")
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
df_perday.shape
# Out:
# (181, 2)

# %%
df.shape
# Out:
# (149116, 12)

# %%
len(df["transaction_date"].unique())
# Out:
# 181

# %%
df_grouped_prod=df.groupby(["transaction_date","product_category"])["transaction_qty"].sum().reset_index()

# %%
df_grouped_prod.shape
# Out:
# (1373, 3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plt.rc('figure', figsize=(14, 8)) 
plt.rc('font', size=15)

# %%
# Ensure the date column is in datetime format
df_perday["transaction_date"] = pd.to_datetime(df_perday["transaction_date"])
df_perday.set_index("transaction_date", inplace=True)
df_perday = df_perday.asfreq("D")  # Ensure daily frequency
df_perday.sort_index(inplace=True)

# Plot the time series
plt.figure(figsize=(14,5))
plt.plot(df_perday["transaction_qty"], label="Daily Quantity Sold", color="blue")
plt.xlabel("Date")
plt.ylabel("Quantity Sold")
plt.title("Daily Sales Over Time")
plt.legend()
plt.show()

# %%
result = seasonal_decompose(df_perday["transaction_qty"], model="additive")
fig = result.plot()
plt.show()

# %%
result = adfuller(df_perday["transaction_qty"].dropna())
print(f"ADF Statistic: {result[0]}")
print(f"p-value: {result[1]}")

if result[1] < 0.05:
    print("Time series is stationary")
else:
    print("Time series is non-stationary. Differencing might be needed.")
# Out:
# ADF Statistic: -0.12031808615858587
# p-value: 0.9473767910109038
# Time series is non-stationary. Differencing might be needed.

# %%
plot_acf(df_perday["transaction_qty"], lags=30)
plt.show()

plot_pacf(df_perday["transaction_qty"], lags=30)
plt.show()

# %%
# Set (p, d, q) and (P, D, Q, m) based on ACF/PACF
sarima_model = SARIMAX(df_perday["transaction_qty"], 
                       order=(3,1,1),  # Reduced AR term
                       seasonal_order=(1,1,1,7),  
                       enforce_stationarity=False, 
                       enforce_invertibility=False)


sarima_result = sarima_model.fit()
print(sarima_result.summary())
# Out:
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                   transaction_qty   No. Observations:                  181
# Model:             SARIMAX(3, 1, 1)x(1, 1, 1, 7)   Log Likelihood               -1011.042
# Date:                           Wed, 19 Feb 2025   AIC                           2036.085
# Time:                                   22:17:03   BIC                           2057.741
# Sample:                               01-01-2023   HQIC                          2044.877
#                                     - 06-30-2023
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2796      0.119      2.355      0.019       0.047       0.512
# ar.L2         -0.0459      0.090     -0.509      0.611      -0.223       0.131
# ar.L3          0.0365      0.102      0.357      0.721      -0.164       0.237
# ma.L1         -0.8778      0.080    -10.930      0.000      -1.035      -0.720
# ar.S.L7       -0.0046      0.112     -0.041      0.967      -0.224       0.215
# ma.S.L7       -1.1004      0.086    -12.758      0.000      -1.269      -0.931
# sigma2       1.12e+04   1948.024      5.748      0.000    7379.096     1.5e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                18.10
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.09   Skew:                            -0.65
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast for next 30 days
future_steps = 30
forecast = sarima_result.get_forecast(steps=future_steps)
forecast_index = pd.date_range(start=df_perday.index[-1], periods=future_steps+1, freq='D')[1:]
forecast_mean = forecast.predicted_mean

# Plot actual vs predicted
plt.figure(figsize=(16,5))
plt.plot(df_perday["transaction_qty"], label="Actual Sales", color="blue")
plt.plot(forecast_index, forecast_mean, label="Forecast", color="red")
plt.xlabel("Date")
plt.ylabel("Quantity Sold")
plt.title("SARIMA Forecast of Daily Sales")
plt.legend()
plt.show()

# %%
predictions = sarima_result.predict()

# %%
# Plot actual vs predicted
plt.figure(figsize=(16,5))
plt.plot(df_perday["transaction_qty"], label="Actual Sales", color="blue")
plt.plot(predictions, label="Forecast", color="red")
plt.plot(forecast_index, forecast_mean, color="red")
plt.xlabel("Date")
plt.ylabel("Quantity Sold")
plt.title("SARIMA Forecast of Daily Sales")
plt.legend()
plt.show()

# %%
# Aggregate total quantity sold per day per category
df_daily_sales = df.groupby(["transaction_date"])["transaction_price"].sum().reset_index()

# %%
# Ensure the date column is in datetime format

df_daily_sales.set_index("transaction_date", inplace=True)
df_daily_sales = df_daily_sales.asfreq("D")  # Ensure daily frequency
df_daily_sales.sort_index(inplace=True)

# Plot the time series
plt.figure(figsize=(14,5))
plt.plot(df_daily_sales["transaction_price"], label="Daily Sales", color="blue")
plt.xlabel("Date")
plt.ylabel("Sales Amount")
plt.title("Daily Sales Over Time")
plt.legend()
plt.show()

# %%
result = seasonal_decompose(df_daily_sales["transaction_price"], model="additive")
fig = result.plot()
plt.show()

# %%
result_adf_sales = adfuller(df_daily_sales["transaction_price"].dropna())
print(f"ADF Statistic: {result_adf_sales[0]}")
print(f"p-value: {result_adf_sales[1]}")

if result_adf_sales[1] < 0.05:
    print("Time series is stationary")
else:
    print("Time series is non-stationary. Differencing might be needed.")
# Out:
# ADF Statistic: -0.7085692033124137
# p-value: 0.8445174174763055
# Time series is non-stationary. Differencing might be needed.

# %%
plot_acf(df_daily_sales["transaction_price"], lags=30)
plt.show()

plot_pacf(df_daily_sales["transaction_price"], lags=30)
plt.show()

# %%
# Set (p, d, q) and (P, D, Q, m) based on ACF/PACF
sarima_model_sales = SARIMAX(df_daily_sales["transaction_price"], 
                       order=(1,1,1),  
                       seasonal_order=(1,1,1,7),  
                       enforce_stationarity=False, 
                       enforce_invertibility=False)


sarima_result_sales = sarima_model_sales.fit()
print(sarima_result_sales.summary())
# Out:
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                 transaction_price   No. Observations:                  181
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 7)   Log Likelihood               -1210.115
# Date:                           Thu, 20 Feb 2025   AIC                           2430.230
# Time:                                   01:04:39   BIC                           2445.729
# Sample:                               01-01-2023   HQIC                          2436.522
#                                     - 06-30-2023
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4243      0.110      3.844      0.000       0.208       0.641
# ma.L1         -0.8542      0.077    -11.048      0.000      -1.006      -0.703
# ar.S.L7        0.0727      0.088      0.823      0.411      -0.101       0.246
# ma.S.L7       -0.9999      0.082    -12.143      0.000      -1.161      -0.839
# sigma2      1.346e+05   6.12e-07    2.2e+11      0.000    1.35e+05    1.35e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                36.37
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.06   Skew:                            -0.46
# Prob(H) (two-sided):                  0.01   Kurtosis:                         5.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.74e+27. Standard errors may be unstable.

# %%
predictions_sales = sarima_result_sales.predict()

# %%
# Plot actual vs predicted
plt.figure(figsize=(16,5))
plt.plot(df_daily_sales["transaction_price"], label="Actual Sales", color="blue")
plt.plot(predictions_sales, label="Forecast", color="red")
plt.xlabel("Date")
plt.ylabel("Sales Amount")
plt.title("SARIMA Forecast of Daily Sales")
plt.legend()
plt.show()

# %%
import statsmodels.api as sm

# Get residuals
residuals = sarima_result_sales.resid

# Plot residual time series
plt.figure(figsize=(12,5))
plt.plot(residuals, label="Residuals")
plt.axhline(0, linestyle='--', color='red', alpha=0.7)
plt.title("Residual Plot")
plt.legend()
plt.show()

# Histogram of residuals
plt.figure(figsize=(8,5))
sns.histplot(residuals, bins=30, kde=True)
plt.title("Residual Histogram")
plt.xlabel("Residual Value")
plt.ylabel("Frequency")
plt.show()

# %%
#Autocorrelation & Partial Autocorrelation of Residuals

fig, axes = plt.subplots(1, 2, figsize=(14,5))

sm.graphics.tsa.plot_acf(residuals, ax=axes[0], lags=30)
axes[0].set_title("Autocorrelation (ACF) of Residuals")

sm.graphics.tsa.plot_pacf(residuals, ax=axes[1], lags=30)
axes[1].set_title("Partial Autocorrelation (PACF) of Residuals")

plt.show()

# %%
sm.qqplot(residuals, line='s')
plt.title("QQ Plot of Residuals")
plt.show()

# %%
# SECOND TRIAL USING AUTO ARIMA PARAMETERS
# Set (p, d, q) and (P, D, Q, m) based on ACF/PACF
sarima_model_sales_auto = SARIMAX(df_daily_sales["transaction_price"], 
                       order=(1,1,1),  
                       seasonal_order=(1,0,2,7),  
                       enforce_stationarity=False, 
                       enforce_invertibility=False)


sarima_result_sales_auto = sarima_model_sales_auto.fit()
print(sarima_result_sales_auto.summary())
# Out:
#                                        SARIMAX Results
# ==============================================================================================
# Dep. Variable:                      transaction_price   No. Observations:                  181
# Model:             SARIMAX(1, 1, 1)x(1, 0, [1, 2], 7)   Log Likelihood               -1196.390
# Date:                                Thu, 20 Feb 2025   AIC                           2404.780
# Time:                                        01:16:48   BIC                           2423.379
# Sample:                                    01-01-2023   HQIC                          2412.330
#                                          - 06-30-2023
# Covariance Type:                                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3867      0.152      2.539      0.011       0.088       0.685
# ma.L1         -0.7749      0.102     -7.590      0.000      -0.975      -0.575
# ar.S.L7       -0.4968      0.209     -2.379      0.017      -0.906      -0.088
# ma.S.L7        0.6477      0.216      3.004      0.003       0.225       1.070
# ma.S.L14       0.3209      0.091      3.516      0.000       0.142       0.500
# sigma2      1.249e+05   1.01e+04     12.322      0.000    1.05e+05    1.45e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.24   Jarque-Bera (JB):                36.79
# Prob(Q):                              0.63   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.17   Skew:                             0.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
predictions_sales_auto = sarima_result_sales_auto.predict()

# %%
# Plot actual vs predicted
plt.figure(figsize=(16,5))
plt.plot(df_daily_sales["transaction_price"], label="Actual Sales", color="blue")
plt.plot(predictions_sales_auto, label="Forecast", color="red")
plt.xlabel("Date")
plt.ylabel("Sales Amount")
plt.title("SARIMA Forecast of Daily Sales")
plt.legend()
plt.show()
